# %%
import sys
sys.path.append('/home/ubuntu/workspace/trailmet')

# %%
from datasets.create_ultramnist import CreateUltraMNIST

# %%
root_path = '/home/ubuntu/workspace/datasets/ultramnist/'
base_path = '/home/ubuntu/workspace/datasets/mnist/'

# %%
base_data = 'MNIST'

# %%
obj_umnist = CreateUltraMNIST(root_path, base_path, 'MNIST')

# %%
obj_umnist.generate_dataset()
# Out:
# Checking for base dataset, if needed
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: /home/ubuntu/workspace/datasets/mnist/
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            )
# Preparing storage locations
# torch.Size([3, 1, 28, 28]) torch.Size([3])
# tensor([9, 6, 9])
# 40
# 2
# 36
# tensor(24)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3465: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
